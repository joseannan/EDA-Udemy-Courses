# %% [markdown]
# # UDEMY COURSES

# %% [markdown]
# Udemy is a massive online open course (MOOC) platform that offers both free and paid courses. Anybody can create a course, a business model by which allowed Udemy to have hundreds of thousands of courses.

# %% [markdown]
# **Dataset information**:
#
# This data contains records of courses from 4 subject taken from Udemy:
#
# -	Course ID - course id
# -	Course Title - course title
# -	Url - course URL
# -	Is_paid - whether the course is free or paid
# -	Price - course price
# -	Number of subscribers - no of subscribers
# -	Number of reviews - no of reviews
# -	Number of lectures - No of lectures
# -	Level - course difficulty
# -	Content Duration - duration of all course materials
# -	Published Timestamp - date that the course was published.
# -	Subject- course subject
#
# **Questions**
# 1. How many courses on Udemy are paid and how are free?
# 2. What is the total number of subscribers ,reviews and lectures on  Udemy?
# 3. Which subject category has the highest subscribers, lectures, reviews and courses?
# 4. Which level has the highest subscribers and courses?
# 5. How many subscribers are paying and how many are not?
# 6. How many courses are paid or free in each subject?
# 7. Total sales earned by Udemy?
# 8. How much sales was made per subject?
# 9. Which level brought in the highest sales??
# 10. Is there a relation between price and the number of subscribers?
# 11. Is there a relation between price and the number of reviews?
# 12. Is there a relation between number of lectures and the number of subscribers?
# 13. Does the content duration have an effect on the number of subscribers?

# %%
#import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#read udemy.csv file
data=pd.read_csv("udemy_courses_1.csv")
df=data.copy()

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.shape
# Out:
# (3678, 13)

# %% [markdown]
# **Observation**: There are 3678 rows and 12 columns

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# Sales                    int64
# dtype: object

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
#  12  Sales                3678 non-null   int64
# dtypes: bool(1), float64(1), int64(6), object(5)
# memory usage: 348.5+ KB

# %% [markdown]
# ## Data Preprocessing

# %%
#Are there any missing values
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# Sales                  0
# dtype: int64

# %% [markdown]
# **Observation**
# - There are no missing values in this data set

# %% [markdown]
# ## Data Examination

# %%
#This is to look at the unique vales in this dataset
#How many subjects are there ?
#What are the prices of variuos courses?
#Are all courses paid?
#what are the various levels of each of the subjects?
list_col=['subject','price','is_paid','level']
for col in list_col: 
     print('{} :{} ' . format(col.upper(),df[col].unique()))
# Out:
# SUBJECT :['Business Finance' 'Graphic Design' 'Musical Instruments'
#  'Web Development']
# PRICE :[200  75  45  95 150  65 195  30  20  50 175 140 115 190 125  60 145 105
#  155 185 180 120  25 160  40   0 100  90  35  80  70  55 165 130  85 170
#  110 135]
# IS_PAID :[ True False]
# LEVEL :['All Levels' 'Intermediate Level' 'Beginner Level' 'Expert Level']

# %% [markdown]
# **Observation**
# - There are four different subjects offered,they are Business Finance, Web Development, Musical Instruments and Graphic Design.
# - The price ranges for the various courses is from 0 to 200.
# - The courses are both paid or unpaid.
# - The subjects may be all levels, beginner, intermediate or expect level.

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration         Sales
# count       3678.000000  3.678000e+03
# mean           4.094517  2.405985e+05
# std            6.053840  1.001404e+06
# min            0.000000  0.000000e+00
# 25%            1.000000  1.585000e+03
# ...

# %% [markdown]
# **Observation**
# - The average price for a course is 66 dollars.
# - The average number of subscribers is 3,197 with a maximum of 268,923.
# - The average number of lectures for a subject is 50 and the maximum is 779.
# - The average number of reviews is 156 with a maximum of 27,445.
# - The average content duration is 4hrs with a maximum of 79hrs.
# - The maximum sales from the subjects is 24.3 million dollars.

# %%
df[df['subject'] == 'Web Development'].describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  1.200000e+03  1200.000000      1200.000000   1200.000000    1200.00000
# mean   7.068543e+05    77.033333      6650.476667    358.354167      52.81750
# std    3.289244e+05    66.080477     14613.648207   1574.814468      62.81375
# min    8.324000e+03     0.000000        19.000000      0.000000       5.00000
# 25%    4.757115e+05    20.000000      1127.500000     25.000000      19.00000
# 50%    7.384560e+05    50.000000      2416.500000     65.000000      32.00000
# 75%    9.752715e+05   115.000000      6894.750000    179.250000      63.25000
# max    1.277924e+06   200.000000    268923.000000  27445.000000     779.00000
#
#        content_duration         Sales
# count       1200.000000  1.200000e+03
# mean           5.594792  5.257031e+05
# std            7.249553  1.579716e+06
# min            0.500000  0.000000e+00
# 25%            1.500000  2.929000e+04
# ...

# %% [markdown]
# **Observation**
# - The average price for a Web Development is 77 dollars.
# - The average number of subscribers for this subject is 6650 with a maximum of 268,923.
# - The average number of lectures for this subject is 53 and the maximum is 779.
# - The average number of reviews is 358 with a maximum of 27,445.
# - The average content duration is 6hrs with a maximum of 77hrs.
# - The average sales from this subject is 525,703 dollar with a maximum of 24.3 million dollars.

# %%
df[df['subject'] == 'Musical Instruments'].describe()
# Out:
#           course_id       price  num_subscribers  num_reviews  num_lectures  \
# count  6.800000e+02  680.000000       680.000000   680.000000    680.000000
# mean   6.386484e+05   49.558824      1245.130882    46.652941     38.316176
# std    3.472305e+05   41.187592      5676.381419   337.735677     42.739700
# min    1.221400e+04    0.000000         0.000000     0.000000      4.000000
# 25%    3.383060e+05   20.000000        31.000000     2.000000     14.000000
# 50%    6.533970e+05   40.000000       138.000000     5.000000     25.000000
# 75%    9.172400e+05   50.000000       870.250000    17.000000     43.000000
# max    1.272282e+06  200.000000    101154.000000  7676.000000    362.000000
#
#        content_duration         Sales
# count        680.000000  6.800000e+02
# mean           2.854387  7.846920e+04
# std            3.470463  6.438852e+05
# min            0.483333  0.000000e+00
# 25%            1.000000  6.000000e+02
# 50%            2.000000  3.970000e+03
# ...

# %% [markdown]
# **Observation**
# - The average price for a Musical Instruments  is 50 dollars.
# - The average number of subscribers for this subject is 1245 with a maximum of 101,154.
# - The average number of lectures for this subject is 38 and the maximum is 362.
# - The average number of reviews is 47 with a maximum of 7,676.
# - The average content duration is 3hrs with a maximum of 38hrs.
# - The average sales from this subject is 78,469 dollar with a maximum of 15 million dollars.

# %%
df[df['subject'] == 'Graphic Design'].describe()
# Out:
#           course_id       price  num_subscribers  num_reviews  num_lectures  \
# count  6.030000e+02  603.000000       603.000000   603.000000    603.000000
# mean   7.202733e+05   57.827529      1763.097844    61.475954     32.054726
# std    3.475865e+05   57.211708      4923.176517   213.061096     31.351326
# min    1.546700e+04    0.000000         0.000000     0.000000      5.000000
# 25%    4.484990e+05   20.000000        34.500000     3.000000     12.500000
# 50%    7.336540e+05   30.000000       384.000000    10.000000     21.000000
# 75%    1.023416e+06   80.000000      1443.500000    31.000000     39.000000
# max    1.276020e+06  200.000000     53851.000000  2379.000000    225.000000
#
#        content_duration         Sales
# count        603.000000  6.030000e+02
# mean           3.580542  1.276669e+05
# std            5.903737  4.914191e+05
# min            0.500000  0.000000e+00
# 25%            1.000000  6.600000e+02
# 50%            2.000000  9.840000e+03
# ...

# %% [markdown]
# **Observation**
# - The average price for a Graphic Design  is 58 dollars.
# - The average number of subscribers for this subject is 1763 with a maximum of 53,851.
# - The average number of lectures for this subject is 32 and the maximum is 225.
# - The average number of reviews is 61 with a maximum of 2,379.
# - The average content duration is 3.6hrs with a maximum of 78hrs.
# - The average sales from this subject is 127,667 dollar with a maximum of 7.3 million dollars.

# %%
df[df['subject'] == 'Business Finance'].describe()
# Out:
#           course_id        price  num_subscribers  num_reviews  num_lectures  \
# count  1.195000e+03  1195.000000      1195.000000  1195.000000   1195.000000
# mean   6.438444e+05    68.552301      1563.774895    63.516318     32.430962
# std    3.478300e+05    64.379824      3912.875791   235.841315     45.442889
# min    1.965300e+04     0.000000         0.000000     0.000000      0.000000
# 25%    3.646880e+05    20.000000        57.500000     3.000000     13.000000
# 50%    6.290600e+05    45.000000       484.000000    12.000000     22.000000
# 75%    9.293360e+05    95.000000      1599.000000    38.000000     36.000000
# max    1.282064e+06   200.000000     65576.000000  4397.000000    544.000000
#
#        content_duration         Sales
# count       1195.000000  1.195000e+03
# mean           3.552999  1.035442e+05
# std            5.665659  3.206855e+05
# min            0.000000  0.000000e+00
# 25%            1.000000  9.350000e+02
# 50%            2.000000  1.254000e+04
# ...

# %% [markdown]
# **Observation**
# - The average price for a Business Finance is 69 dollars.
# - The average number of subscribers for this subject is 1564 with a maximum of 65,576.
# - The average number of lectures for this subject is 32 and the maximum is 544.
# - The average number of reviews is 64 with a maximum of 4397.
# - The average content duration is 3.6hrs with a maximum of 72hrs.
# - The average sales from this subject is 103,544 dollar with a maximum of 4.8 million dollars.

# %%
#How many subscribers does Udemy have in total?
df.num_subscribers.sum()
# Out:
# 11759120

# %%
#What is the total number of reviews?
df.num_reviews.sum()
# Out:
# 574721

# %% [markdown]
# # VISUALIZATIONS AND INSIGHTS

# %%
#How many courses are in each subject category?  
df.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("DISTRIBUTION OF SUBJECTS",fontsize=16,fontweight='bold')
df.subject.value_counts().plot(kind='bar',color="purple")
# Out:
# <AxesSubplot:title={'center':'DISTRIBUTION OF SUBJECTS'}>

# %%
#How many courses are paid or free?
df.is_paid.value_counts()
# Out:
# True     3368
# False     310
# Name: is_paid, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("DISTRIBUTION OF IS_PAID",fontsize=16,fontweight='bold')
df.is_paid.value_counts().plot(kind='bar',color="mediumvioletred")
# Out:
# <AxesSubplot:title={'center':'DISTRIBUTION OF IS_PAID'}>

# %%
# Number of courses in each type of level
df.level.value_counts()
# Out:
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("DISTRIBUTION OF LEVEL",fontsize=16,fontweight='bold')
colors=('mediumvioletred','purple','#F9EE5D','yellowgreen')
df.level.value_counts().plot(kind='pie',colors=colors,autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'DISTRIBUTION OF LEVEL'}, ylabel='level'>

# %% [markdown]
# **Observation**
# - There are 1200 courses on Web Development,603 on Graphic Design,1195 on Business Finance and 680 on Musical Instruments.
# - 3368 courses on Udemy are paid and 310 are for free.
# - The most courses are in all level followed by beginner with least number of courses being in expert level.

# %%
#How many lectures are in each subject category?
df.groupby('subject')['num_lectures'].sum()
# Out:
# subject
# Business Finance       38755
# Graphic Design         19329
# Musical Instruments    26055
# Web Development        63381
# Name: num_lectures, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("DISTRIBUTION OF LECTURES BASED ON SUBJECTS",fontsize=16,fontweight='bold')
df.groupby('subject')['num_lectures'].sum().plot(kind='bar',color="mediumvioletred")
# Out:
# <AxesSubplot:title={'center':'DISTRIBUTION OF LECTURES BASED ON SUBJECTS'}, xlabel='subject'>

# %%
#How many lectures does each level have?
df.groupby('level')['num_lectures'].sum()
# Out:
# level
# All Levels            88698
# Beginner Level        41908
# Expert Level           1785
# Intermediate Level    15129
# Name: num_lectures, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("DISTRIBUTION OF LECTURES BASED LEVEL",fontsize=16,fontweight='bold')
df.groupby('level')['num_lectures'].sum().plot(kind='bar',color="yellowgreen")
# Out:
# <AxesSubplot:title={'center':'DISTRIBUTION OF LECTURES BASED ON LEVEL'}, xlabel='level'>

# %%
#How many reviews does each subject category have? 
df.groupby('subject')['num_reviews'].sum()
# Out:
# subject
# Business Finance        75902
# Graphic Design          37070
# Musical Instruments     31724
# Web Development        430025
# Name: num_reviews, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("DISTRIBUTION OF NUMBER OF REVIEWS BASED ON SUBJECTS",fontsize=16,fontweight='bold')
colors=('mediumvioletred','purple','#F9EE5D','yellowgreen')
df.groupby('subject')['num_reviews'].sum().plot(kind='pie',colors=colors,autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'DISTRIBUTION OF NUMBER OF REVIEWS BASED ON SUBJECTS'}, ylabel='num_reviews'>

# %%
#what is the number of reviews for each level?
df.groupby('level')['num_reviews'].sum()
# Out:
# level
# All Levels            404297
# Beginner Level        129075
# Expert Level            2333
# Intermediate Level     39016
# Name: num_reviews, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("DISTRIBUTION OF NUMBER OF REVIEWS BASED ON LEVEL",fontsize=16,fontweight='bold')
colors=('mediumvioletred','purple','#F9EE5D','yellowgreen')
df.groupby('level')['num_reviews'].sum().plot(kind='pie',colors=colors,autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'DISTRIBUTION OF NUMBER OF REVIEWS BASED ON LEVEL'}, ylabel='num_reviews'>

# %% [markdown]
# **Observation**
# - Web development has the highest number of lectures with Graphic design having the least.
# - There are more lectures being all level and less in expert level.
# - Web development has more reviews than the other subjects.
# - The all level subcategory has the highest number of reviews.

# %%
#How many people have subscribed to the various subjects?
df.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1868711
# Graphic Design         1063148
# Musical Instruments     846689
# Web Development        7980572
# Name: num_subscribers, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.title("NUMBER OF SUBSCRIBERS PER SUBJECT",fontsize=16,fontweight='bold')
df.groupby('subject')['num_subscribers'].sum().plot(kind='bar',color="#F9EE5D")
# Out:
# <AxesSubplot:title={'center':'NUMBER OF SUBSCRIBERS PER SUBJECT'}, xlabel='subject'>

# %%
#How many subscribers does each level have?
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6915076
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.title("NUMBER OF SUBSCRIBERS OF EACH LEVEL",fontsize=16,fontweight='bold')
df.groupby('level')['num_subscribers'].sum().plot(kind='bar',color="yellowgreen")
# Out:
# <AxesSubplot:title={'center':'NUMBER OF SUBSCRIBERS OF EACH LEVEL'}, xlabel='level'>

# %%
#How many subscribers are paying and how many are not?
df.groupby('is_paid')['num_subscribers'].sum()
# Out:
# is_paid
# False    3575525
# True     8183595
# Name: num_subscribers, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("DISTRIBUTION OF SUBSCRIBERS BASED ON IS_PAID",fontsize=16,fontweight='bold')
colors=('#F9EE5D','yellowgreen')
df.groupby('is_paid')['num_subscribers'].sum().plot(kind='pie',colors=colors,autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'DISTRIBUTION OF SUBSCRIBERS BASED ON IS_PAID'}, ylabel='num_subscribers'>

# %% [markdown]
# **Observation**
# - Web Development has the highest number of subscribers beingh approx. 7.9 million.
# - Musical Instruments has the least number of subscribers being approx. 846,689.
# - All level subcategory has 6.9 million subscribers making it the level with the highest subscription.
# - 8.2 million subscribers are paying for the courses they are undertaking.
# - 3.6 million subscribers have subscribed to courses that are offered for free.

# %%
#How many courses per levels per subject?
df.groupby('subject')['level'].value_counts()
# Out:
# subject              level
# Business Finance     All Levels            696
#                      Beginner Level        340
#                      Intermediate Level    128
#                      Expert Level           31
# Graphic Design       All Levels            298
#                      Beginner Level        243
#                      Intermediate Level     57
#                      Expert Level            5
# Musical Instruments  Beginner Level        296
#                      All Levels            276
#                      Intermediate Level    101
#                      Expert Level            7
# Web Development      All Levels            659
#                      Beginner Level        391
#                      Intermediate Level    135
#                      Expert Level           15
# Name: level, dtype: int64

# %%
#courses per levels per subject
plt.figure(figsize=(12,8))
plt.title("NUMBER OF COURSES OF EACH LEVEL PER SUBJECT",fontsize=16,fontweight='bold')
df.groupby('subject')['level'].value_counts().plot(kind='bar',color="yellowgreen")
# Out:
# <AxesSubplot:title={'center':'NUMBER OF COURSES OF EACH LEVEL PER SUBJECT'}, xlabel='subject,level'>

# %%
#Plotting the number of subscribers at each level per subject.
plt.figure(figsize=(12,8))
plt.title("NUMBER OF SUBSCRIBERS OF EACH LEVEL PER SUBJECT",fontsize=16,fontweight='bold')
color = ['purple','yellowgreen','#F9EE5D','mediumvioletred']
sns.set_palette(color)
sns.barplot(x='level',y='num_subscribers',hue='subject',data=df,ci=None)
# Out:
# <AxesSubplot:title={'center':'NUMBER OF SUBSCRIBERS OF EACH LEVEL PER SUBJECT'}, xlabel='level', ylabel='num_subscribers'>

# %%
#how many courses are paid or free in each subject?
df.groupby('is_paid')['subject'].value_counts()
# Out:
# is_paid  subject
# False    Web Development         133
#          Business Finance         96
#          Musical Instruments      46
#          Graphic Design           35
# True     Business Finance       1099
#          Web Development        1067
#          Musical Instruments     634
#          Graphic Design          568
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.title("PAID OR FREE COURSES PER SUBJECT",fontsize=16,fontweight='bold')
df.groupby('is_paid')['subject'].value_counts().plot(kind='bar',color="purple")
# Out:
# <AxesSubplot:title={'center':'PAID OR FREE COURSES PER SUBJECT'}, xlabel='is_paid,subject'>

# %%
#Plotting the paid or free subscriptions per subject
plt.figure(figsize=(12,8))
plt.title("PAID OR FREE SUBSCRIPTIONS PER SUBJECT",fontsize=16,fontweight='bold')
color = ['purple','yellowgreen','#F9EE5D','mediumvioletred']
sns.set_palette(color)
sns.barplot(x='is_paid',y='num_subscribers',hue='subject',data=df,ci=None)
# Out:
# <AxesSubplot:title={'center':'PAID OR FREE SUBSCRIPTIONS PER SUBJECT'}, xlabel='is_paid', ylabel='num_subscribers'>

# %%
##Number of reviews per level per subject
plt.figure(figsize=(12,8))
plt.title("REVIEWS AT EACH LEVEL PER SUBJECT",fontsize=16,fontweight='bold')
color = ['purple','yellowgreen','#F9EE5D','mediumvioletred']
sns.set_palette(color)
sns.barplot(x='level',y='num_reviews',hue='subject',data=df,ci=None)
# Out:
# <AxesSubplot:title={'center':'REVIEWS AT EACH LEVEL PER SUBJECT'}, xlabel='level', ylabel='num_reviews'>

# %%
#Number of reviews per level per subject
plt.figure(figsize=(12,8))
plt.title("LECTURES AT EACH LEVEL PER SUBJECT",fontsize=16,fontweight='bold')
color = ['purple','yellowgreen','#F9EE5D','mediumvioletred']
sns.set_palette(color)
sns.barplot(x='level',y='num_lectures',hue='subject',data=df,ci=None)
# Out:
# <AxesSubplot:title={'center':'LECTURES AT EACH LEVEL PER SUBJECT'}, xlabel='level', ylabel='num_lectures'>

# %%
#Total sales made by Udemy
df.Sales.sum()
# Out:
# 884921315

# %%
#How much sales was made per subject?
df.groupby('subject')['Sales'].sum()
# Out:
# subject
# Business Finance       123735315
# Graphic Design          76983170
# Musical Instruments     53359055
# Web Development        630843775
# Name: Sales, dtype: int64

# %%
#Plotting sales made on based on subject.
plt.figure(figsize=(10,8))
plt.title("SALES BASED ON SUBJECTS",fontsize=16,fontweight='bold')
colors=('mediumvioletred','purple','#F9EE5D','yellowgreen')
df.groupby('subject')['Sales'].sum().plot(kind='pie',colors=colors,autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'SALES BASED ON SUBJECTS'}, ylabel='Sales'>

# %%
#How much sales was made per level?
df.groupby('level')['Sales'].sum()
# Out:
# level
# All Levels            610039770
# Beginner Level        219678340
# Expert Level            5469070
# Intermediate Level     49734135
# Name: Sales, dtype: int64

# %%
#Plotting sales made on based on subject.
plt.figure(figsize=(10,8))
plt.title("SALES BASED ON EACH LEVEL",fontsize=16,fontweight='bold')
colors=('mediumvioletred','purple','#F9EE5D','yellowgreen')
df.groupby('level')['Sales'].sum().plot(kind='pie',colors=colors,autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'SALES BASED ON EACH LEVEL'}, ylabel='Sales'>

# %% [markdown]
# **Observation**
# - Approximately 885 million dollars of sales were made in total.
# - The Web Development subject had the highest sales of approx. 631 million dollars.
# - The Business finance had the second highest sales of approx. 124 million dollars.
# - Musical instrument subject brought in just 6% of the total sales making it the least.
# - All level has the highest sales of approx. 610 million dollars.
# - The beginner level had the second highest sales of approx. 220 million dollars.
# - The expert level brought in just 0.6% of the total sales making it the least.

# %%
#Does price influence the number of subcribers?
plt.figure(figsize=(10,8))
plt.title("PRICE INFLUENCE ON THE NUMBER OF SUBSCRIBERS",fontsize=16,fontweight='bold')
sns.scatterplot(data=df,x='price',y='num_subscribers')
# Out:
# <AxesSubplot:title={'center':'PRICE INFLUENCE ON THE NUMBER OF SUBSCRIBERS'}, xlabel='price', ylabel='num_subscribers'>

# %% [markdown]
# **Observation**
# - Prices influence subscription since there are more subscribers when the price is 0 dollar.
# - There is notable amount of subscribers at price 200 dollars since price maybe associated with quality.

# %%
#Does price influence the number of reviews?
plt.figure(figsize=(10,8))
plt.title("PRICE INFLUENCE ON THE NUMBER OF REVIEWS",fontsize=16,fontweight='bold')
sns.scatterplot(data=df,x='price',y='num_reviews')
# Out:
# <AxesSubplot:title={'center':'PRICE INFLUENCE ON THE NUMBER OF REVIEWS'}, xlabel='price', ylabel='num_reviews'>

# %%
#Does the number of reviews influence the number of subscribers? 
plt.figure(figsize=(12,8))
plt.title("NUMBER OF REVIEWS INFLUENCE ON THE NUMBER OF SUBSCRIBERS",fontsize=16,fontweight='bold')
sns.lineplot(data=df,x='num_reviews',y='num_subscribers',hue='subject')
# Out:
# <AxesSubplot:title={'center':'NUMBER OF REVIEWS INFLUENCE ON THE NUMBER OF SUBSCRIBERS'}, xlabel='num_reviews', ylabel='num_subscribers'>

# %% [markdown]
# **Observation**
# - There is some inflence made by number of reviews on the number of subscribers.
# - There are more subscribers when reviews are in the ranges of 0 and 10000.

# %%
#Does the number of lectures made on courses influence the number of subscribers?
plt.figure(figsize=(12,8))
plt.title("NUMBER OF LECTURES INFLUENCE ON THE NUMBER OF SUBSCRIBERS",fontsize=16,fontweight='bold')
sns.lineplot(data=df,x='num_lectures',y='num_subscribers',hue='subject')
# Out:
# <AxesSubplot:title={'center':'NUMBER OF LECTURES INFLUENCE ON THE NUMBER OF SUBSCRIBERS'}, xlabel='num_lectures', ylabel='num_subscribers'>

# %% [markdown]
# **Observation**
# - There is some inflence made by number of lectures on the number of subscribers.
# - There are more subscribers when lectures are in the ranges of 0 and 450.

# %%
#Does the content duration have an effect on the number of subscribers?
plt.figure(figsize=(10,8))
plt.title("CONTENT DURATION INFLUENCE ON THE NUMBER OF SUBSCRIBERS",fontsize=16,fontweight='bold')
sns.scatterplot(data=df,x='content_duration',y='num_subscribers',hue='subject')
# Out:
# <AxesSubplot:title={'center':'CONTENT DURATION INFLUENCE ON THE NUMBER OF SUBSCRIBERS'}, xlabel='content_duration', ylabel='num_subscribers'>

# %% [markdown]
# **Observation**
# - Content duration has significant influence on the subscriptions since there is a concentration
# of subscribers in range of 0-30hrs.

# %% [markdown]
# **Recommendations**
#
# Based on this analysis, we recommend that:
# - Udemy creates on develops more courses in Web Development since it has more subscribers and brings in the highest sales.
# - In order to increase subscription with other subject category ,Udemy has to focus on offering most of the courses in all level since most subscribers prefer that.
# - Although more subscribers are paying for the courses, a significant number are also subscribed to free courses therefore they can create some more courses for free and subsequently advertise the benefits of undertaken paid courses.
# - To increase subscription to the other subject category apart from Web development, they can reduces the price slightly .
# - The duration of content has an influence on the number of subscribers therefore Udemy can try to reduce the duration to 40 and below. This will be beneficial since their most profitable course has most of it subscribers signing up to contents with duration below 20 hrs.
